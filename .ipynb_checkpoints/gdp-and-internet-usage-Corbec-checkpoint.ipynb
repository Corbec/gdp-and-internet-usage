# %% [markdown]
# Import the required packages with their customary aliases

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# 5. Using the pandas read_csv() method, read the GDP dataset into your notebook as a DataFrame called gdp_df. Take a look at the first 6 rows.

# %%
gdp_df = pd.read_csv('data/gdp_percapita.csv', nrows = 6729)

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  1734.723214              NaN
# 1     Afghanistan  2017  1758.465636              NaN
# 2     Afghanistan  2016  1757.023490              NaN
# 3     Afghanistan  2015  1766.593077              NaN
# 4     Afghanistan  2014  1795.735834              NaN
# 5     Afghanistan  2013  1807.762344              NaN

# %% [markdown]
# 6. Repeat for the internet use dataset. Call this DataFrame internet_df. Take a look at the first six rows.

# %%
internet_df = pd.read_csv('data/internet_use.csv', nrows = 4495)

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %% [markdown]
# 7. Look at the shape of each DataFrame - how many rows? How many columns?

# %%
gdp_df.shape
# Out:
# (6729, 4)

# %% [markdown]
# gdp_df has 4 columns and 6,729 rows.

# %%
internet_df.shape
# Out:
# (4495, 4)

# %% [markdown]
# internet_df has 4 columns and 4,495 rows.

# %% [markdown]
# 8. Take a look at the datatypes for the columns in each DataFrame.

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# 9. Take a look at the last 10 rows of each DataFrame in turn.

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6719        Zimbabwe  1999  3054.064189              NaN
# 6720        Zimbabwe  1998  3099.076182              NaN
# 6721        Zimbabwe  1997  3036.422224              NaN
# 6722        Zimbabwe  1996  2985.856605              NaN
# 6723        Zimbabwe  1995  2736.486436              NaN
# 6724        Zimbabwe  1994  2768.309953              NaN
# 6725        Zimbabwe  1993  2572.870395              NaN
# 6726        Zimbabwe  1992  2591.007534              NaN
# 6727        Zimbabwe  1991  2906.272849              NaN
# 6728        Zimbabwe  1990  2819.549467              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# 10. Drop the value footnotes column from both DataFrames. Check that this worked as expected.

# %%
gdp_df = gdp_df.drop(columns = 'Value Footnotes')
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2018  1734.723214
# 1        Afghanistan  2017  1758.465636
# 2        Afghanistan  2016  1757.023490
# 3        Afghanistan  2015  1766.593077
# 4        Afghanistan  2014  1795.735834
# ...              ...   ...          ...
# 6724        Zimbabwe  1994  2768.309953
# 6725        Zimbabwe  1993  2572.870395
# 6726        Zimbabwe  1992  2591.007534
# 6727        Zimbabwe  1991  2906.272849
# 6728        Zimbabwe  1990  2819.549467
#
# [6729 rows x 3 columns]

# %%
internet_df = internet_df.drop(columns = 'Value Footnotes')
internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 11. Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area':'Country', 'Value':'GDP_Per_Capita'})
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2018     1734.723214
# 1     Afghanistan  2017     1758.465636
# 2     Afghanistan  2016     1757.023490
# 3     Afghanistan  2015     1766.593077
# 4     Afghanistan  2014     1795.735834
# ...           ...   ...             ...
# 6724     Zimbabwe  1994     2768.309953
# 6725     Zimbabwe  1993     2572.870395
# 6726     Zimbabwe  1992     2591.007534
# 6727     Zimbabwe  1991     2906.272849
# 6728     Zimbabwe  1990     2819.549467
#
# [6729 rows x 3 columns]

# %% [markdown]
# 12. Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df = internet_df.rename(columns = {'Country or Area':'Country', 'Value':'Internet_Users_Pct'})
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 13. Merge the two DataFrames to one. Merge all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use.

# %%
gdp_and_internet_use = gdp_df.merge(internet_df, how = 'outer')
gdp_and_internet_use
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0               Afghanistan  2018     1734.723214                 NaN
# 1               Afghanistan  2017     1758.465636                 NaN
# 2               Afghanistan  2016     1757.023490                 NaN
# 3               Afghanistan  2015     1766.593077                 NaN
# 4               Afghanistan  2014     1795.735834            6.390000
# ...                     ...   ...             ...                 ...
# 7700  Virgin Islands (U.S.)  1997             NaN            6.948369
# 7701  Virgin Islands (U.S.)  1996             NaN            4.647186
# 7702  Virgin Islands (U.S.)  1995             NaN            2.801958
# 7703  Virgin Islands (U.S.)  1994             NaN            0.940645
# 7704  Virgin Islands (U.S.)  1990             NaN            0.000000
#
# [7705 rows x 4 columns]

# %% [markdown]
# 14. Look at the first five rows of your new DataFrame to confirm it merged correctly.

# %%
gdp_and_internet_use.head(5)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2018     1734.723214                 NaN
# 1  Afghanistan  2017     1758.465636                 NaN
# 2  Afghanistan  2016     1757.023490                 NaN
# 3  Afghanistan  2015     1766.593077                 NaN
# 4  Afghanistan  2014     1795.735834                6.39

# %% [markdown]
# 15. Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use.tail()
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7700  Virgin Islands (U.S.)  1997             NaN            6.948369
# 7701  Virgin Islands (U.S.)  1996             NaN            4.647186
# 7702  Virgin Islands (U.S.)  1995             NaN            2.801958
# 7703  Virgin Islands (U.S.)  1994             NaN            0.940645
# 7704  Virgin Islands (U.S.)  1990             NaN            0.000000

# %% [markdown]
# 16. Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
gdp_and_internet_subset = gdp_and_internet_use[(gdp_and_internet_use['Year'] == 2004)| 
                                               (gdp_and_internet_use['Year'] == 2009)| 
                                               (gdp_and_internet_use['Year'] == 2014)]

# %%
gdp_and_internet_subset
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4               Afghanistan  2014     1795.735834            6.390000
# 9               Afghanistan  2009     1502.354073            3.550000
# 14              Afghanistan  2004     1025.208245            0.105809
# 21                  Albania  2014    10700.993216           60.100000
# 26                  Albania  2009     9525.377979           41.200000
# ...                     ...   ...             ...                 ...
# 7668               Viet Nam  2009             NaN           26.550000
# 7673               Viet Nam  2004             NaN            7.642409
# 7683  Virgin Islands (U.S.)  2014             NaN           50.070000
# 7688  Virgin Islands (U.S.)  2009             NaN           27.396510
# 7693  Virgin Islands (U.S.)  2004             NaN           27.377009
#
# [835 rows x 4 columns]

# %% [markdown]
# 17. Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
gdp_and_int_2004 = gdp_and_internet_subset[gdp_and_internet_subset['Year'] == 2004]
gdp_and_int_2004
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 14              Afghanistan  2004     1025.208245            0.105809
# 31                  Albania  2004     7001.054082            2.420388
# 60                  Algeria  2004    11845.170512            4.634475
# 89                   Angola  2004     4604.657044            0.464815
# 118     Antigua and Barbuda  2004    21161.123532           24.266544
# ...                     ...   ...             ...                 ...
# 7551              Swaziland  2004             NaN            3.228685
# 7572                  Syria  2004             NaN            4.321594
# 7615     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7673               Viet Nam  2004             NaN            7.642409
# 7693  Virgin Islands (U.S.)  2004             NaN           27.377009
#
# [278 rows x 4 columns]

# %%
gdp_and_int_2009 = gdp_and_internet_subset[gdp_and_internet_subset['Year'] == 2009]
gdp_and_int_2009
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 9               Afghanistan  2009     1502.354073             3.55000
# 26                  Albania  2009     9525.377979            41.20000
# 55                  Algeria  2009    12697.690780            11.23000
# 84                   Angola  2009     6292.534856             6.00000
# 113     Antigua and Barbuda  2009    22568.626530            42.00000
# ...                     ...   ...             ...                 ...
# 7546              Swaziland  2009             NaN             8.94000
# 7567                  Syria  2009             NaN            17.30000
# 7610     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 7668               Viet Nam  2009             NaN            26.55000
# 7688  Virgin Islands (U.S.)  2009             NaN            27.39651
#
# [279 rows x 4 columns]

# %%
gdp_and_int_2014 = gdp_and_internet_subset[gdp_and_internet_subset['Year'] == 2014]
gdp_and_int_2014
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4               Afghanistan  2014     1795.735834                6.39
# 21                  Albania  2014    10700.993216               60.10
# 50                  Algeria  2014    13557.769757               18.09
# 79                   Angola  2014     6813.052106               21.26
# 108     Antigua and Barbuda  2014    20440.540555               64.00
# ...                     ...   ...             ...                 ...
# 7541              Swaziland  2014             NaN               27.10
# 7562                  Syria  2014             NaN               28.09
# 7605     T.F.Y.R. Macedonia  2014             NaN               68.06
# 7663               Viet Nam  2014             NaN               48.31
# 7683  Virgin Islands (U.S.)  2014             NaN               50.07
#
# [278 rows x 4 columns]

# %% [markdown]
# 18. Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).

# %%
gdp_and_int_2014[gdp_and_int_2014['Internet_Users_Pct'] == gdp_and_int_2014.Internet_Users_Pct.max()]
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2581  Iceland  2014    42774.888849               98.16

# %% [markdown]
# Iceland had the highest percent of internet users in 2014. The percentage was 98.16%

# %% [markdown]
# 19. Which country had the lowest percentage of internet users in 2014? What was the percentage?

# %%
gdp_and_int_2014[gdp_and_int_2014['Internet_Users_Pct'] == gdp_and_int_2014.Internet_Users_Pct.min()]
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6940  Dem. People's Rep. of Korea  2014             NaN                 0.0

# %% [markdown]
# The Democratic People's Republic of Korea had the lowest percentage of internet usage in 2014, with 0.0%.

# %% [markdown]
# 20. Repeat for 2004 and 2009.

# %%
gdp_and_int_2004[gdp_and_int_2004['Internet_Users_Pct'] == gdp_and_int_2004.Internet_Users_Pct.max()]
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5852  Sweden  2004    40177.850408               83.89

# %% [markdown]
# The country with the highest internet usage percent in 2004 was Sweden, with 83.89%.

# %%
gdp_and_int_2004[gdp_and_int_2004['Internet_Users_Pct'] == gdp_and_int_2004.Internet_Users_Pct.min()]
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6949  Dem. People's Rep. of Korea  2004             NaN                 0.0

# %% [markdown]
# The country with the lowest internet use percentage in 2004 was again North Korea, with 0.0%.

# %%
gdp_and_int_2009[gdp_and_int_2009['Internet_Users_Pct'] == gdp_and_int_2009.Internet_Users_Pct.max()]
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2586  Iceland  2009    41505.084834                93.0

# %% [markdown]
# Iceland was also the country with the highest percentage of internet use in 2009, with 93.0%.

# %%
gdp_and_int_2009[gdp_and_int_2009['Internet_Users_Pct'] == gdp_and_int_2009.Internet_Users_Pct.min()]
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6944  Dem. People's Rep. of Korea  2009             NaN                 0.0

# %% [markdown]
# Once again, North Korea was at the bottom of internet usage in 2009 with 0.0%.

# %% [markdown]
# 21. Which country had the highest gdp per capita in 2014? What was the gdp per capita?

# %%
gdp_and_int_2014[gdp_and_int_2014['GDP_Per_Capita'] == gdp_and_int_2014.GDP_Per_Capita.max()]
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3639  Macao SAR, China  2014   130439.106674                 NaN

# %% [markdown]
# Macao SAR, China has the highest GDP in 2014 with 130,439.11.

# %% [markdown]
# 22. Which country had the lowest gdp per capita in 2014? What was the gdp per capita?

# %%
gdp_and_int_2014[gdp_and_int_2014['GDP_Per_Capita'] == gdp_and_int_2014.GDP_Per_Capita.min()]
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1014  Central African Republic  2014      672.681648                 NaN

# %% [markdown]
# The Central African Republic had the lowest GDP in 2014 with 672.68.

# %% [markdown]
# 23. Create some scatterplots:
#     a. 2004 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_and_int_2004)
plt.xlabel('Internet Use')
plt.ylabel('GDP Per Capita');

# %% [markdown]
#     b. 2009 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_and_int_2009)
plt.xlabel('Internet Use')
plt.ylabel('GDP Per Capita');

# %% [markdown]
#     c. 2014 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_and_int_2014)
plt.xlabel('Internet Use')
plt.ylabel('GDP Per Capita');

# %% [markdown]
# 24. Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.

# %% [markdown]
# There are differences across the years. Internet use has increased in general. Earlier internet use was more tied to GDP than later, with the scatter plot at its densest in the lower left corner in 2004. The scatter plots have spread more evenly over time, with a better distribution of the datapoints throughiut data usage.

# %% [markdown]
# 25. Look at the distribution of gdp per capita values for 2014. Is it unimodal?

# %%
plt.hist(gdp_and_int_2014['GDP_Per_Capita'], bins = 20)
plt.xlabel('GDP Per Capita')
plt.ylabel('Countries');

#sns.distplot(gdp_and_int_2014['GDP_Per_Capita'])
#plt.xlabel('GDP_Per_Capita')
# Out:
# C:\Users\sarei\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\sarei\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# It is unimodal and skewed to the right.

# %% [markdown]
# 26. Look at the distribution of Internet Use for 2014. Is it unimodal?

# %%
plt.hist(gdp_and_int_2014['Internet_Users_Pct'], bins = 20)
plt.xlabel('Internet Users Percentage')
plt.ylabel('Countries');

# %% [markdown]
# It is not unimodal.

# %% [markdown]
# 27. What are the top 5 countries in terms of internet use in 2014?

# %%
gdp_and_int_2014.sort_values(by = 'Internet_Users_Pct', ascending = False).head()
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2581  Iceland  2014    42774.888849               98.16
# 6772  Bermuda  2014             NaN               96.80
# 4530   Norway  2014    63328.259526               96.30
# 1404  Denmark  2014    45057.083449               95.99
# 6732  Andorra  2014             NaN               95.90

# %% [markdown]
# The top five countries for internet use in 2014 are Iceland, Bermuda, Norway, Denmark, and Andorra.

# %% [markdown]
# 28. Create a DataFrame called top_5_internet from the combined DataFrame that has all three years for the 5 countries that had the greatest 2014 internet usage. You should have 15 rows. Check that this is true.

# %%
#top_5_internet = gdp_and_internet_subset[(gdp_and_internet_subset['Country'] == 'Iceland') |
                                        #(gdp_and_internet_subset['Country'] == 'Bermuda') |
                                        #(gdp_and_internet_subset['Country'] == 'Norway') |
                                        #(gdp_and_internet_subset['Country'] == 'Denmark') |
                                        #(gdp_and_internet_subset['Country'] == 'Andorra')]

# %%
#top_5_internet

# %%
top_5 = ['Iceland', 'Bermuda', 'Denmark', 'Norway', 'Andorra']
top_5_internet = gdp_and_internet_subset.query('Country in @top_5')
top_5_internet.shape

# Hailey's
#top_5_internet = pd.concat([top_int_2004, top_int_2009, top_int_2014])
#top_5_internet=top_5_internet.reset_index(drop=True)
#top_5_internet.shape
# Out:
# (15, 4)

# %% [markdown]
# 29. Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014? Is there a plotting issue with Bermuda? Can you fix it?

# %%
top_5_grid = sns.FacetGrid(top_5_internet, col = 'Country')
top_5_grid.map(sns.scatterplot, 'Year', 'Internet_Users_Pct')
top_5_grid.set_axis_labels('Year', 'Internet Use Percent');

# %%
top_5_internet = top_5_internet.sort_values(by = 'Country')

# %%
top_5_internet
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6732  Andorra  2014             NaN           95.900000
# 6737  Andorra  2009             NaN           78.530000
# 6742  Andorra  2004             NaN           26.837954
# 542   Bermuda  2009    57151.919132           83.250000
# 547   Bermuda  2004    55452.638880           60.990867
# 6772  Bermuda  2014             NaN           96.800000
# 1404  Denmark  2014    45057.083449           95.990000
# 1409  Denmark  2009    43382.615688           86.840000
# 1414  Denmark  2004    43670.446201           80.930000
# 2581  Iceland  2014    42774.888849           98.160000
# 2586  Iceland  2009    41505.084834           93.000000
# 2591  Iceland  2004    38893.378798           83.880000
# 4530   Norway  2014    63328.259526           96.300000
# 4535   Norway  2009    62617.153609           92.080000
# 4540   Norway  2004    61612.275634           77.690000

# %% [markdown]
# Andorra had the largest difference in internet use between 2004 and 2014. I did not see a plotting issue with Bermuda.

# %% [markdown]
# 30. Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use?

# %%
gdp_and_int_2014.min()
# Out:
# Country               Afghanistan
# Year                         2014
# GDP_Per_Capita            672.682
# Internet_Users_Pct              0
# dtype: object

# %%
gdp_and_int_2014.sort_values(by = 'Internet_Users_Pct', ascending = True).head()
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6940  Dem. People's Rep. of Korea  2014             NaN                0.00
# 6999                      Eritrea  2014             NaN                0.99
# 6044                  Timor-Leste  2014     6466.737732                1.14
# 794                       Burundi  2014      768.469837                1.38
# 7521                      Somalia  2014             NaN                1.63

# %%
bottom_5 = ['Dem. People\'s Rep. of Korea', 'Eritrea', 'Timor-Leste', 'Burundi', 'Somalia']
bottom_5_internet = gdp_and_internet_subset.query('Country in @bottom_5')
bottom_5_internet.shape
# Out:
# (15, 4)

# %%
bottom_5_grid = sns.FacetGrid(bottom_5_internet, col = 'Country')
bottom_5_grid.map(sns.scatterplot, 'Year', 'Internet_Users_Pct')
bottom_5_grid.set_axis_labels('Year', 'Internet Use Percent');

# %% [markdown]
# North Korea has consistently had the lowest internet use.

# %% [markdown]
# 31. Find the top 5 countries for 2014 in terms of GDP per capita; create a DataFrame to look at 10-year trends (use 2004, 2009, 2014 to look at the 10-year trend) in gdp per capita for the 5 countries with the highest 2014 GDP per capita. Use a seaborn facet grid for this.

# %%
gdp_and_int_2014.sort_values(by = 'GDP_Per_Capita', ascending = False).head()
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3639  Macao SAR, China  2014   130439.106674                 NaN
# 5003             Qatar  2014   116693.507701               91.49
# 3610        Luxembourg  2014    92349.186429               94.67
# 5316         Singapore  2014    81965.361071               82.00
# 707             Brunei  2014    76448.593329                 NaN

# %%
top_5 = ['Macao SAR, China', 'Quatar', 'Luxembourg', 'Singapore', 'Brunei']
top_5_gdp = gdp_and_internet_subset.query('Country in @top_5')
top_5_internet.shape
# Out:
# (15, 4)

# %%
top_5_grid = sns.FacetGrid(top_5_gdp, col = 'Country')
top_5_grid.map(sns.scatterplot, 'Year', 'GDP_Per_Capita')
top_5_grid.set_axis_labels('Year', 'GDP Per Capita');

# %% [markdown]
# 32. Repeat this one more time to look at 10-year trend for the 5 countries for 2014 with the lowest GDP per capita.

# %%
gdp_and_int_2014.sort_values(by = 'GDP_Per_Capita', ascending = True).head()
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1014  Central African Republic  2014      672.681648                 NaN
# 794                    Burundi  2014      768.469837                1.38
# 1375           Dem. Rep. Congo  2014      784.872656                 NaN
# 4414                     Niger  2014      900.136918                1.95
# 3697                    Malawi  2014     1142.530804                5.83

# %%
bottom_5 = ['Central African Republic', 'Burundi', 'Dem. Rep. Congo', 'Niger', 'Malawi']
bottom_5_internet = gdp_and_internet_subset.query('Country in @bottom_5')
bottom_5_internet.shape
# Out:
# (15, 4)

# %%
bottom_5_grid = sns.FacetGrid(bottom_5_internet, col = 'Country')
bottom_5_grid.map(sns.scatterplot, 'Year', 'GDP_Per_Capita')
bottom_5_grid.set_axis_labels('Year', 'GDP Per Capita');

# %% [markdown]
# 33. Is there anything surprising or unusual in any of these plots? Searching on the internet, can you find any possible explanations for unusual findings?

# %% [markdown]
# The Central African Republic's GDP took a sharp downturn after 2009. Some searching shows that there was a lot of rebel activity and that the UN sent in peacekeepers to try to stabilize the region. Brunei's GDP has also decreased over this timeframe. The economy of Brunei is largely connected to oil and gas. Lower gas prices and an increase in alternate energy sources seems to have made an impact. Macao's large GDP seems to stem from a loosening in travel restrictions for residents of mainland China. Macao is essently the Las Vegas of China and has a relatively low population of 650,000.

# %% [markdown]
# Bonus. Download another data set from the UN data (http://data.un.org/Explorer.aspx) to merge with your data and explore.

# %% [markdown]
# Adding in a dataset that has country population over the age of 15, along with education level.

# %%
pop_df = pd.read_csv('data/country_population.csv', nrows = 99999)

# %% [markdown]
# nrows used to leave the footnotes off of the data.

# %%
pop_df
# Out:
#       Country or Area  Year   Area         Sex      Age  \
# 0       Åland Islands  2000  Total  Both Sexes  15 - 19
# 1       Åland Islands  2000  Total  Both Sexes  15 - 19
# 2       Åland Islands  2000  Total  Both Sexes  15 - 19
# 3       Åland Islands  2000  Total  Both Sexes  15 - 19
# 4       Åland Islands  2000  Total  Both Sexes  15 - 19
# ...               ...   ...    ...         ...      ...
# 99994           Tonga  2006  Total        Male  50 - 54
# 99995           Tonga  2006  Total        Male  50 - 54
# 99996           Tonga  2006  Total        Male  50 - 54
# 99997           Tonga  2006  Total        Male  50 - 54
# 99998           Tonga  2006  Total        Male  50 - 54
#
#                                   Educational attainment  \
# 0               ISCED 1997 - Primary education (Level 1)
# 1       ISCED 1997 - Upper secondary education (Level 3)
# 2        ISCED 1997 - Post-secondary education (Level 4)
# 3      ISCED 1997 - First stage of tertiary education...
# ...

# %%
pop_df.dtypes
# Out:
# Country or Area            object
# Year                        int64
# Area                       object
# Sex                        object
# Age                        object
# Educational attainment     object
# Record Type                object
# Reliability                object
# Source Year                 int64
# Value                     float64
# Value Footnotes            object
# dtype: object

# %%
pop_df = pop_df.drop(columns = ['Value Footnotes', 'Area', 'Record Type', 'Reliability', 'Source Year'])

# %% [markdown]
# Dropping columns that are not needed.

# %%
pop_df
# Out:
#       Country or Area  Year         Sex      Age  \
# 0       Åland Islands  2000  Both Sexes  15 - 19
# 1       Åland Islands  2000  Both Sexes  15 - 19
# 2       Åland Islands  2000  Both Sexes  15 - 19
# 3       Åland Islands  2000  Both Sexes  15 - 19
# 4       Åland Islands  2000  Both Sexes  15 - 19
# ...               ...   ...         ...      ...
# 99994           Tonga  2006        Male  50 - 54
# 99995           Tonga  2006        Male  50 - 54
# 99996           Tonga  2006        Male  50 - 54
# 99997           Tonga  2006        Male  50 - 54
# 99998           Tonga  2006        Male  50 - 54
#
#                                   Educational attainment   Value
# 0               ISCED 1997 - Primary education (Level 1)  1320.0
# 1       ISCED 1997 - Upper secondary education (Level 3)    97.0
# 2        ISCED 1997 - Post-secondary education (Level 4)    45.0
# 3      ISCED 1997 - First stage of tertiary education...     0.0
# ...

# %%
pop_df = pop_df.rename(columns = {'Country or Area':'Country', 'Value':'Population', 
                                  'Educational attainment':'Education'})

# %% [markdown]
# Changing column names.

# %%
pop_df
# Out:
#              Country  Year         Sex      Age  \
# 0      Åland Islands  2000  Both Sexes  15 - 19
# 1      Åland Islands  2000  Both Sexes  15 - 19
# 2      Åland Islands  2000  Both Sexes  15 - 19
# 3      Åland Islands  2000  Both Sexes  15 - 19
# 4      Åland Islands  2000  Both Sexes  15 - 19
# ...              ...   ...         ...      ...
# 99994          Tonga  2006        Male  50 - 54
# 99995          Tonga  2006        Male  50 - 54
# 99996          Tonga  2006        Male  50 - 54
# 99997          Tonga  2006        Male  50 - 54
# 99998          Tonga  2006        Male  50 - 54
#
#                                                Education  Population
# 0               ISCED 1997 - Primary education (Level 1)      1320.0
# 1       ISCED 1997 - Upper secondary education (Level 3)        97.0
# 2        ISCED 1997 - Post-secondary education (Level 4)        45.0
# 3      ISCED 1997 - First stage of tertiary education...         0.0
# ...

# %% [markdown]
# Merging gdp_and_internet_use with pop_df.

# %%
gdp_int_and_pop_full = pop_df.merge(gdp_and_internet_use, how = 'inner')

# %%
gdp_int_and_pop_full
# Out:
#        Country  Year         Sex      Age  \
# 0      Albania  2011  Both Sexes  15 - 19
# 1      Albania  2011  Both Sexes  15 - 19
# 2      Albania  2011  Both Sexes  15 - 19
# 3      Albania  2011  Both Sexes  15 - 19
# 4      Albania  2011  Both Sexes  15 - 19
# ...        ...   ...         ...      ...
# 83945    Tonga  2006        Male  50 - 54
# 83946    Tonga  2006        Male  50 - 54
# 83947    Tonga  2006        Male  50 - 54
# 83948    Tonga  2006        Male  50 - 54
# 83949    Tonga  2006        Male  50 - 54
#
#                                                Education  Population  \
# 0                              ISCED 1997 - No education      1641.0
# 1               ISCED 1997 - Primary education (Level 1)     12923.0
# 2       ISCED 1997 - Lower secondary education (Level 2)    170573.0
# 3       ISCED 1997 - Upper secondary education (Level 3)     77650.0
# 4      ISCED 1997 - First stage of tertiary education...       174.0
# ...

# %% [markdown]
# Finding the country with the highest population.

# %%
years = [2004, 2009, 2014]
gdp_int_and_pop_sub = gdp_int_and_pop_full.query('Year in @years')
gdp_int_and_pop_sub
# Out:
#            Country  Year         Sex      Age  \
# 4026    Azerbaijan  2009  Both Sexes  15 - 19
# 4027    Azerbaijan  2009  Both Sexes  15 - 19
# 4028    Azerbaijan  2009  Both Sexes  15 - 19
# 4029    Azerbaijan  2009  Both Sexes  15 - 19
# 4030    Azerbaijan  2009  Both Sexes  15 - 19
# ...            ...   ...         ...      ...
# 83152  Timor-Leste  2004      Female     65 +
# 83153  Timor-Leste  2004      Female     65 +
# 83154  Timor-Leste  2004      Female     65 +
# 83155  Timor-Leste  2004      Female     65 +
# 83156  Timor-Leste  2004      Female     65 +
#
#                                               Education  Population  \
# 4026                          ISCED 1997 - No education       415.0
# 4027           ISCED 1997 - Primary education (Level 1)     13872.0
# 4028   ISCED 1997 - Lower secondary education (Level 2)    512903.0
# 4029   ISCED 1997 - Upper secondary education (Level 3)    377156.0
# ...

# %%
gdp_int_and_pop_sub[gdp_int_and_pop_sub['Population'] == gdp_int_and_pop_sub.Population.max()]
# Out:
#        Country  Year         Sex   Age          Education  Population  \
# 57210  Myanmar  2014  Both Sexes  15 +  ISCED 1997, Total  35880331.0
#
#        GDP_Per_Capita  Internet_Users_Pct
# 57210     4737.459861                 2.1

# %%
gdp_int_and_pop_sub[gdp_int_and_pop_sub.Internet_Users_Pct == gdp_int_and_pop_sub.Internet_Users_Pct.max()]
# Out:
#        Country  Year         Sex      Age  \
# 27597  Georgia  2014  Both Sexes  15 - 19
# 27598  Georgia  2014  Both Sexes  15 - 19
# 27599  Georgia  2014  Both Sexes  15 - 19
# 27600  Georgia  2014  Both Sexes  15 - 19
# 27601  Georgia  2014  Both Sexes  15 - 19
# ...        ...   ...         ...      ...
# 28176  Georgia  2014      Female  Unknown
# 28177  Georgia  2014      Female  Unknown
# 28178  Georgia  2014      Female  Unknown
# 28179  Georgia  2014      Female  Unknown
# 28180  Georgia  2014      Female  Unknown
#
#                                                Education  Population  \
# 27597                          ISCED 1997 - No education       583.0
# 27598       ISCED 1997 - Pre-primary education (Level 0)       354.0
# 27599           ISCED 1997 - Primary education (Level 1)     14747.0
# 27600   ISCED 1997 - Lower secondary education (Level 2)    130583.0
# 27601   ISCED 1997 - Upper secondary education (Level 3)     76348.0
# ...

# %%
gdp_int_and_pop_sub[gdp_int_and_pop_sub.Internet_Users_Pct == gdp_int_and_pop_sub.Internet_Users_Pct.min()]
# Out:
#       Country  Year         Sex   Age  \
# 30950  Guinea  2014  Both Sexes  15 +
# 30951  Guinea  2014  Both Sexes  15 +
# 30952  Guinea  2014  Both Sexes  15 +
# 30953  Guinea  2014  Both Sexes  15 +
# 30954  Guinea  2014  Both Sexes  15 +
# 30955  Guinea  2014  Both Sexes  15 +
# 30956  Guinea  2014  Both Sexes  15 +
# 30957  Guinea  2014  Both Sexes  15 +
# 30958  Guinea  2014        Male  15 +
# 30959  Guinea  2014        Male  15 +
# 30960  Guinea  2014        Male  15 +
# 30961  Guinea  2014        Male  15 +
# 30962  Guinea  2014        Male  15 +
# 30963  Guinea  2014        Male  15 +
# 30964  Guinea  2014        Male  15 +
# 30965  Guinea  2014        Male  15 +
# 30966  Guinea  2014      Female  15 +
# 30967  Guinea  2014      Female  15 +
# 30968  Guinea  2014      Female  15 +
# 30969  Guinea  2014      Female  15 +
# 30970  Guinea  2014      Female  15 +
# 30971  Guinea  2014      Female  15 +
# 30972  Guinea  2014      Female  15 +
# ...

# %%
gdp_int_and_pop_sub[gdp_int_and_pop_sub.Country == 'Iceland']
# Out:
# Empty DataFrame
# Columns: [Country, Year, Sex, Age, Education, Population, GDP_Per_Capita, Internet_Users_Pct]
# Index: []

# %% [markdown]
# After a little exploration of the population data I brought in fot the bonus question, it became clear that the data did not include some of the countries I was interested in exploring. I found data that included those countries and broke the population down by urban/rural.

# %%
urban_rural_df = pd.read_csv('data/urban_rural_pop.csv', nrows = 65520)

# %%
urban_rural_df
# Out:
#       Country or Area  Year   Area         Sex          Record Type  \
# 0         Afghanistan  2019  Total  Both Sexes  Estimate - de facto
# 1         Afghanistan  2019  Total        Male  Estimate - de facto
# 2         Afghanistan  2019  Total      Female  Estimate - de facto
# 3         Afghanistan  2019  Urban  Both Sexes  Estimate - de facto
# 4         Afghanistan  2019  Urban        Male  Estimate - de facto
# ...               ...   ...    ...         ...                  ...
# 65515        Zimbabwe  1955  Total  Both Sexes  Estimate - de facto
# 65516        Zimbabwe  1954  Total  Both Sexes  Estimate - de facto
# 65517        Zimbabwe  1953  Total  Both Sexes  Estimate - de facto
# 65518        Zimbabwe  1952  Total  Both Sexes  Estimate - de facto
# 65519        Zimbabwe  1951  Total  Both Sexes  Estimate - de facto
#
#                                              Reliability  Source Year  \
# 0      Final figure, incomplete/questionable reliability         2019
# ...

# %%
urban_rural_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Area                object
# Sex                 object
# Record Type         object
# Reliability         object
# Source Year          int64
# Value              float64
# Value Footnotes     object
# dtype: object

# %%
urban_rural_df = urban_rural_df.drop(columns = ['Value Footnotes', 'Record Type', 'Reliability', 'Source Year'])

# %%
urban_rural_df
# Out:
#       Country or Area  Year   Area         Sex       Value
# 0         Afghanistan  2019  Total  Both Sexes  30725560.0
# 1         Afghanistan  2019  Total        Male  15643288.0
# 2         Afghanistan  2019  Total      Female  15082272.0
# 3         Afghanistan  2019  Urban  Both Sexes   7761765.0
# 4         Afghanistan  2019  Urban        Male   3921208.0
# ...               ...   ...    ...         ...         ...
# 65515        Zimbabwe  1955  Total  Both Sexes   3270000.0
# 65516        Zimbabwe  1954  Total  Both Sexes   3170000.0
# 65517        Zimbabwe  1953  Total  Both Sexes   2530000.0
# 65518        Zimbabwe  1952  Total  Both Sexes   2430000.0
# 65519        Zimbabwe  1951  Total  Both Sexes   2330000.0
#
# [65520 rows x 5 columns]

# %%
urban_rural_df = urban_rural_df.rename(columns = {'Country or Area':'Country', 'Value':'Population'})

# %%
gdp_int_and_urban_full = urban_rural_df.merge(gdp_and_internet_use, how = 'inner')

# %%
gdp_int_and_urban_full
# Out:
#            Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 0      Afghanistan  2018  Total  Both Sexes  30075018.0     1734.723214
# 1      Afghanistan  2018  Total        Male  15312423.0     1734.723214
# 2      Afghanistan  2018  Total      Female  14762595.0     1734.723214
# 3      Afghanistan  2018  Urban  Both Sexes   7507953.0     1734.723214
# 4      Afghanistan  2018  Urban        Male   3792857.0     1734.723214
# ...            ...   ...    ...         ...         ...             ...
# 30721     Zimbabwe  1992  Total  Both Sexes  10412548.0     2591.007534
# 30722     Zimbabwe  1992  Total  Both Sexes  10412548.0     2591.007534
# 30723     Zimbabwe  1992  Total        Male   5083537.0     2591.007534
# 30724     Zimbabwe  1992  Total      Female   5329011.0     2591.007534
# 30725     Zimbabwe  1990  Total  Both Sexes   9369000.0     2819.549467
#
#        Internet_Users_Pct
# 0                     NaN
# 1                     NaN
# ...

# %% [markdown]
# Subset into years 2004, 2009, 2014

# %%
years = [2004, 2009, 2014]
gdp_int_and_urban_sub = gdp_int_and_urban_full.query('Year in @years')
gdp_int_and_urban_sub
# Out:
#            Country  Year   Area         Sex    Population  GDP_Per_Capita  \
# 36     Afghanistan  2014  Total  Both Sexes  2.655675e+07     1795.735834
# 37     Afghanistan  2014  Total        Male  1.358593e+07     1795.735834
# 38     Afghanistan  2014  Total      Female  1.297082e+07     1795.735834
# 39     Afghanistan  2014  Urban  Both Sexes  6.483434e+06     1795.735834
# 40     Afghanistan  2014  Urban        Male  3.338764e+06     1795.735834
# ...            ...   ...    ...         ...           ...             ...
# 30644     Zimbabwe  2004  Urban        Male  2.004961e+06     2104.143512
# 30645     Zimbabwe  2004  Urban      Female  2.058816e+06     2104.143512
# 30646     Zimbabwe  2004  Rural  Both Sexes  7.666223e+06     2104.143512
# 30647     Zimbabwe  2004  Rural        Male  3.676785e+06     2104.143512
# 30648     Zimbabwe  2004  Rural      Female  3.989439e+06     2104.143512
#
#        Internet_Users_Pct
# 36               6.390000
# ...

# %% [markdown]
# Reset the scientific notation in the Population column.

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
gdp_int_and_urban_sub[gdp_int_and_urban_sub['Population'] == gdp_int_and_urban_sub.Population.max()]
# Out:
#      Country  Year   Area         Sex    Population  GDP_Per_Capita  \
# 6234   China  2014  Total  Both Sexes 1364270000.00        12725.09
#
#       Internet_Users_Pct
# 6234               49.30

# %%
gdp_int_and_urban_sub[gdp_int_and_urban_sub['Population'] == gdp_int_and_urban_sub.Population.min()]
# Out:
#          Country  Year   Area     Sex  Population  GDP_Per_Capita  \
# 11568  Greenland  2014  Rural  Female     3641.00             nan
#
#        Internet_Users_Pct
# 11568               66.70

# %% [markdown]
# Subset further into an urban and a rural set, with population numbers made up of both sexes.

# %%
gdp_int_and_urban_sub = gdp_int_and_urban_sub[gdp_int_and_urban_sub['Sex'] == 'Both Sexes']

# %%
urban_both = gdp_int_and_urban_sub[gdp_int_and_urban_sub.Area == 'Urban']

# %%
urban_both
# Out:
#            Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 39     Afghanistan  2014  Urban  Both Sexes  6483434.00         1795.74
# 84     Afghanistan  2009  Urban  Both Sexes  5507300.00         1502.35
# 129    Afghanistan  2004  Urban  Both Sexes  4668700.00         1025.21
# 233        Albania  2009  Urban  Both Sexes  1518397.00         9525.38
# 278        Albania  2004  Urban  Both Sexes  1396981.00         7001.05
# ...            ...   ...    ...         ...         ...             ...
# 30311        Yemen  2009  Urban  Both Sexes  6475802.00         4359.81
# 30342        Yemen  2004  Urban  Both Sexes  5637756.00         4145.35
# 30438       Zambia  2014  Urban  Both Sexes  6235786.00         3684.69
# 30577     Zimbabwe  2014  Urban  Both Sexes  4535793.00         2506.49
# 30643     Zimbabwe  2004  Urban  Both Sexes  4063777.25         2104.14
#
#        Internet_Users_Pct
# 39                   6.39
# 84                   3.55
# ...

# %%
rural_both = gdp_int_and_urban_sub[gdp_int_and_urban_sub.Area == 'Rural']

# %%
rural_both
# Out:
#            Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 42     Afghanistan  2014  Rural  Both Sexes 20073320.00         1795.74
# 87     Afghanistan  2009  Rural  Both Sexes 18486200.00         1502.35
# 132    Afghanistan  2004  Rural  Both Sexes 17009000.00         1025.21
# 236        Albania  2009  Rural  Both Sexes  1409122.00         9525.38
# 281        Albania  2004  Rural  Both Sexes  1629958.00         7001.05
# ...            ...   ...    ...         ...         ...             ...
# 30312        Yemen  2009  Rural  Both Sexes 16016233.00         4359.81
# 30345        Yemen  2004  Rural  Both Sexes 14047405.00         4145.35
# 30441       Zambia  2014  Rural  Both Sexes  8787529.00         3684.69
# 30580     Zimbabwe  2014  Rural  Both Sexes  9157755.00         2506.49
# 30646     Zimbabwe  2004  Rural  Both Sexes  7666222.75         2104.14
#
#        Internet_Users_Pct
# 42                   6.39
# 87                   3.55
# ...

# %% [markdown]
# Explore if urban or rural populations have more internet usage.

# %%
urban_both[urban_both['Internet_Users_Pct'] == urban_both.Internet_Users_Pct.max()]
# Out:
#        Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 13126  Iceland  2014  Urban  Both Sexes   306632.50        42774.89
#
#        Internet_Users_Pct
# 13126               98.16

# %%
urban_both[urban_both['Internet_Users_Pct'] == urban_both.Internet_Users_Pct.min()]
# Out:
#        Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 19872  Myanmar  2004  Urban  Both Sexes 16416487.00         1999.71
#
#        Internet_Users_Pct
# 19872                0.02

# %%
rural_both[rural_both['Internet_Users_Pct'] == rural_both.Internet_Users_Pct.max()]
# Out:
#        Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 13129  Iceland  2014  Rural  Both Sexes    20753.00        42774.89
#
#        Internet_Users_Pct
# 13129               98.16

# %%
rural_both[rural_both['Internet_Users_Pct'] == rural_both.Internet_Users_Pct.min()]
# Out:
#        Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 19875  Myanmar  2004  Rural  Both Sexes 37883006.00         1999.71
#
#        Internet_Users_Pct
# 19875                0.02

# %% [markdown]
# Create a subset to urban_both and rural_both to get only information for 2014.

# %%
urban_both_2014 = urban_both[urban_both.Year == 2014]
urban_both_2014
# Out:
#            Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 39     Afghanistan  2014  Urban  Both Sexes  6483434.00         1795.74
# 621         Angola  2014  Urban  Both Sexes 16153987.00         6813.05
# 622         Angola  2014  Urban  Both Sexes 16235542.00         6813.05
# 814      Argentina  2014  Urban  Both Sexes 39021268.00        18935.00
# 1045       Armenia  2014  Urban  Both Sexes  1913481.00         7954.20
# ...            ...   ...    ...         ...         ...             ...
# 29848   Uzbekistan  2014  Urban  Both Sexes 15651614.00         6498.14
# 30153     Viet Nam  2014  Urban  Both Sexes 30035405.00             nan
# 30286        Yemen  2014  Urban  Both Sexes  7488311.82         3828.48
# 30438       Zambia  2014  Urban  Both Sexes  6235786.00         3684.69
# 30577     Zimbabwe  2014  Urban  Both Sexes  4535793.00         2506.49
#
#        Internet_Users_Pct
# 39                   6.39
# 621                 21.26
# ...

# %%
rural_both_2014 = rural_both[rural_both.Year == 2014]
rural_both_2014
# Out:
#            Country  Year   Area         Sex  Population  GDP_Per_Capita  \
# 42     Afghanistan  2014  Rural  Both Sexes 20073320.00         1795.74
# 627         Angola  2014  Rural  Both Sexes  9635037.00         6813.05
# 628         Angola  2014  Rural  Both Sexes  9665640.00         6813.05
# 817      Argentina  2014  Rural  Both Sexes  3648232.00        18935.00
# 1048       Armenia  2014  Rural  Both Sexes  1100358.00         7954.20
# ...            ...   ...    ...         ...         ...             ...
# 29851   Uzbekistan  2014  Rural  Both Sexes 15106055.00         6498.14
# 30154     Viet Nam  2014  Rural  Both Sexes 60693536.00             nan
# 30287        Yemen  2014  Rural  Both Sexes 18467608.17         3828.48
# 30441       Zambia  2014  Rural  Both Sexes  8787529.00         3684.69
# 30580     Zimbabwe  2014  Rural  Both Sexes  9157755.00         2506.49
#
#        Internet_Users_Pct
# 42                   6.39
# 627                 21.26
# ...

# %% [markdown]
# Highest five countries for urban and rural populations in 2014.

# %%
urban_both_2014.sort_values(by = 'Population', ascending = False).head()
# Out:
#          Country  Year   Area         Sex   Population  GDP_Per_Capita  \
# 6237       China  2014  Urban  Both Sexes 740135000.00        12725.09
# 4201      Brazil  2014  Urban  Both Sexes 173358764.34        15480.87
# 13652  Indonesia  2014  Urban  Both Sexes 132387038.00        10003.17
# 18704     Mexico  2014  Urban  Both Sexes  86782031.46        17149.78
# 28290     Turkey  2014  Urban  Both Sexes  67720318.00        22343.50
#
#        Internet_Users_Pct
# 6237                49.30
# 4201                57.60
# 13652               17.14
# 18704               44.39
# 28290               51.04

# %%
rural_both_2014.sort_values(by = 'Population', ascending = False).head()
# Out:
#           Country  Year   Area         Sex   Population  GDP_Per_Capita  \
# 6238        China  2014  Rural  Both Sexes 624135000.00        12725.09
# 13655   Indonesia  2014  Rural  Both Sexes 119777748.00        10003.17
# 2402   Bangladesh  2014  Rural  Both Sexes 112770000.00         3067.03
# 9646     Ethiopia  2014  Rural  Both Sexes  71218000.00         1413.96
# 30154    Viet Nam  2014  Rural  Both Sexes  60693536.00             nan
#
#        Internet_Users_Pct
# 6238                49.30
# 13655               17.14
# 2402                 9.60
# 9646                 2.90
# 30154               48.31

# %% [markdown]
# Lowest five countries for urban and rural populations in 2014.

# %%
urban_both_2014.sort_values(by = 'Population', ascending = True).head()
# Out:
#                      Country  Year   Area         Sex  Population  \
# 9856           Faroe Islands  2014  Urban  Both Sexes    18373.00
# 24190                  Samoa  2014  Urban  Both Sexes    37128.60
# 11563              Greenland  2014  Urban  Both Sexes    48232.00
# 5687          Cayman Islands  2014  Urban  Both Sexes    58238.00
# 24644  Sao Tome and Principe  2014  Urban  Both Sexes   125121.00
#
#        GDP_Per_Capita  Internet_Users_Pct
# 9856              nan               94.66
# 24190         5271.79               21.20
# 11563             nan               66.70
# 5687         62929.87               74.10
# 24644             nan               24.41

# %%
rural_both_2014.sort_values(by = 'Population', ascending = True).head()
# Out:
#                      Country  Year   Area         Sex  Population  \
# 11566              Greenland  2014  Rural  Both Sexes     8063.00
# 13129                Iceland  2014  Rural  Both Sexes    20753.00
# 9859           Faroe Islands  2014  Rural  Both Sexes    30089.00
# 24647  Sao Tome and Principe  2014  Rural  Both Sexes    60903.00
# 24193                  Samoa  2014  Rural  Both Sexes   155586.80
#
#        GDP_Per_Capita  Internet_Users_Pct
# 11566             nan               66.70
# 13129        42774.89               98.16
# 9859              nan               94.66
# 24647             nan               24.41
# 24193         5271.79               21.20

# %% [markdown]
# It does not appear that higher urban population automatically means higher internet use percentage. The countries with the highest urban populations had mid-range or lower internet use.

# %%
top_5 = ['China', 'Brazil', 'Indonesia', 'Mexico', 'Turkey']
top_5_urban = urban_both.query('Country in @top_5')
top_5_urban.shape
# Out:
# (11, 7)

# %%
bottom_5 = ['Faroe Islands', 'Samoa', 'Greenland', 'Cayman Islands', 'Sao Tome and Principe']
bottom_5_urban = urban_both.query('Country in @bottom_5')
bottom_5_urban.shape
# Out:
# (12, 7)
